# %%
# %matplotlib inline
# %run analysis.py

EXPERIMENT_BASE_PATH = '../ops/results/20200514'
SERVER_NODES = ['node90', 'node91', 'node92']

# %%
# %ls $EXPERIMENT_BASE_PATH
# Out:
# 001server-1client-50sparseness-000conflict-35ops-1k-1ms-NON_POOLED/
# 001server-1client-50sparseness-000conflict-35ops-1k-1ms-POOLED/
# 001server-1client-50sparseness-050conflict-35ops-1k-1ms-NON_POOLED/
# 001server-1client-50sparseness-050conflict-35ops-1k-1ms-POOLED/
# 001server-1client-50sparseness-100conflict-35ops-1k-1ms-NON_POOLED/
# 001server-1client-50sparseness-100conflict-35ops-1k-1ms-POOLED/
# 008server-1client-50sparseness-000conflict-35ops-1k-1ms-NON_POOLED/
# 008server-1client-50sparseness-000conflict-35ops-1k-1ms-POOLED/
# 008server-1client-50sparseness-050conflict-35ops-1k-1ms-NON_POOLED/
# 008server-1client-50sparseness-050conflict-35ops-1k-1ms-POOLED/
# 008server-1client-50sparseness-100conflict-35ops-1k-1ms-NON_POOLED/
# 008server-1client-50sparseness-100conflict-35ops-1k-1ms-POOLED/
# 032server-1client-50sparseness-000conflict-35ops-1k-1ms-NON_POOLED/
# 032server-1client-50sparseness-000conflict-35ops-1k-1ms-POOLED/
# ...

# %% [markdown]
# # Throughput per number of threds (no writes)

# %%
consolidated_throughput_per_thread_and_scheduler(EXPERIMENT_BASE_PATH, SERVER_NODES,
    '*server-1client-50sparseness-000conflict-35ops-1k-1ms-*')

# %% [markdown]
# # Throughput per number of threds (50% writes)

# %%
consolidated_throughput_per_thread_and_scheduler(EXPERIMENT_BASE_PATH, SERVER_NODES,
    '*server-1client-50sparseness-050conflict-35ops-1k-1ms-*')

# %% [markdown]
# # Throughput per number of threds (100% writes)

# %%
consolidated_throughput_per_thread_and_scheduler(EXPERIMENT_BASE_PATH, SERVER_NODES,
    '*server-1client-50sparseness-100conflict-35ops-1k-1ms-*')

# %% [markdown]
# # Thoughput per writes

# %%
consolidated_throughput_per_conflict_and_scheduler(EXPERIMENT_BASE_PATH, SERVER_NODES,
    '032server-1client-50sparseness-*conflict-35ops-1k-1ms-*')
